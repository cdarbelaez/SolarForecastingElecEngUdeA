# %% [markdown]
# <a href="https://colab.research.google.com/github/cdarbelaez/SolarForecastingElecEngUdeA/blob/main/CNN%20GRU/CNN_GRU_Univariable_Array_Standard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CNN_GRU NN UNIVARIABLE**
#
# ---
#
#
# > En este notebook se realiza la implementación de la red neuronal mencionada:
#
# *   Se parte del preprocesamiento y análisis de los datos que **NO** está incluido en este script.
# *   Luego se procede a cargar y escalar el dataset previamente procesado.
# *   Se preparan en ventanas y se separan en set de entrenamiento y validación.
# *   Luego se implementa el modelo de aprendizaje automatico con una arquitectura e hiperparametros previamente establecidos.
# *   Por último se validan los resultados y se obtienen las métricas de error.
#
# > La diferencia principal de este modelo con los demás CNN_GRU es que se utiliza para escalar los datos la función de sklearn `StandardScaler()` y una sola variable de entrada al modelo que es la GHI.
#
#
# ---
#
# **BASE DE DATOS:** KENYA

# %% [markdown]
# ---
# # 1.   **SE IMPORTAN LAS BIBLIOTECAS NECESARIAS**
#
# ---

# %% [markdown]
#   Importamos las librerias necesarias para todo el script:
#
# 1.   **Matplotlib** para realizar las gráficas
# 2.   **Pandas** para procesar la base de datos
# 3.   **Numpy** para convertir la base de datos en arreglos numéricos
# 4.   **Os** para acceder a los archivos mediante rutas de almacenamiento
# 5.   **Seaborn** para realizar análisis gráficos a los datos mediante análisis estadisticos
# 6.   **Drive** se utiliza para acceder a las carpetas de datos del drive de un correo asociado
# 7.   **Tensorflow** es la librería mediante la cual se generan los modelos de redes neuronales

# %%
import tensorflow as tf
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns
from google.colab import drive 
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.preprocessing import StandardScaler

# %%
mpl.rcParams['figure.figsize'] = (8, 6) #Definimos el tamaño para las figuras de matplotlib
mpl.rcParams['axes.grid'] = False

# %% [markdown]
# ---
#
#
# # 2.   **SE CARGA EL DATASET PREVIAMENTE PROCESADO**
#
# ---

# %% [markdown]
# En la siguiente celda de codigo se llama una función de google colab mediante la cual se accede a la carpeta de drive, luego se define la ruta de acceso a la base de datos previamente procesados para la realización del modelo y se procesa mediante la librería `Pandas`:

# %%
ruta= 'https://raw.githubusercontent.com/alvarojd/SolarForecasting/main/DATASETS/INICIAL_LIMPIO.csv'
ruta='https://raw.githubusercontent.com/cdarbelaez/SolarForecastingElecEngUdeA/main/DATABASES/KENYA_LIMPIO.csv'
data = pd.read_csv(ruta,encoding='utf-8') # Se hace la respectiva lectura, no se añade encabezado o indice, por lo que pondrá por defecto la numeracion
if ruta=='https://raw.githubusercontent.com/alvarojd/SolarForecasting/main/DATASETS/INICIAL_LIMPIO.csv':
  data.set_index('datetime', inplace=True)
else:
  data.set_index('time', inplace=True) # Establecemos cual será el indice del dataframe
data.head(2) # Se muestran las 5 primeras filas del dataframe
# Out:
#                      dhi_pyr  ghi_pyr_1  ghi_pyr_2  air_temperature  \
# time
# 2019-12-12 00:00:00      0.0        0.0        0.0         22.72500
# 2019-12-12 00:15:00      0.0        0.0        0.0         22.58083
#
#                      relative_humidity  barometric_pressure  precipitation  \
# time
# 2019-12-12 00:00:00          99.003998           948.445923            0.0
# 2019-12-12 00:15:00          98.758003           948.415283            0.0
#
#                      wind_speed  wind_from_direction  gti_clean  gti_soil  \
# time
# 2019-12-12 00:00:00    1.073283           169.845993        0.0       0.0
# 2019-12-12 00:15:00    0.727417           204.165405        0.0       0.0
#
#                      gti_monthly  sensor_cleaning  Hour
# time
# 2019-12-12 00:00:00          0.0              0.0     0
# 2019-12-12 00:15:00          0.0              0.0     0

# %% [markdown]
# ---
#
#
# # 3. **SE SELECCIONAN LOS DATOS A UTILIZAR PARA EL ENTRENAMIENTO DEL MODELO**
#
#
# ---

# %%
if ruta=='https://raw.githubusercontent.com/alvarojd/SolarForecasting/main/DATASETS/INICIAL_LIMPIO.csv':
  features_considered = ['GHI']# Definimos las columnas que se van a utilizar para el entrenamiento del modelo
  features = data[features_considered].loc['2010-04-07 00:00:00':] # Creamos un dataframe con solo estos datos
else:
  features_considered = ['ghi_pyr_1']
  features = data[features_considered] # Creamos un dataframe con solo estos datos
features.head() #Se muestran los 5 primeros datos
# Out:
#                      ghi_pyr_1
# time
# 2019-12-12 00:00:00        0.0
# 2019-12-12 00:15:00        0.0
# 2019-12-12 00:30:00        0.0
# 2019-12-12 00:45:00        0.0
# 2019-12-12 01:00:00        0.0

# %% [markdown]
# Graficamos todos los datos con el fin de apreciar de manera general su comportamiento a lo largo del tiempo con la función plot asociada a la librería `Pandas`.

# %%
features.plot(subplots=True) # Graficamos las columnas de datos para observar su comportamiento
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f3a5e205690>],
#       dtype=object)

# %% [markdown]
# Se convierte el conjunto de datos en un arreglo de `numpy` definiendo la cantidad de datos que se van a utilizar para el proceso y luego se estandarizan con una normalización:

# %%
TRAIN_SPLIT = int(len(features)*0.8//1) #Definimos la cantidad de datos que se van a usar para el entrenamiento del modelo
dataset = features.values # Convertimos el dataframe en un arreglo de numpy

# %% [markdown]
# ---
#
#
# 3_1. **ESCALAMIENTO DE LOS DATOS**
#
#
# ---

# %%
scaler = StandardScaler()
dataset = scaler.fit_transform(dataset)

# %% [markdown]
# ---
#
#
# # 4.   **SE DEFINE LA FUNCIÓN QUE SE UTILIZA PARA LA PARTICIÓN DE LOS DATOS EN VENTANAS**
#
# ---

# %%
#---------------------------------------
#CONFIGURACIÓN DE LAS VENTANAS DE DATOS#
#---------------------------------------
DATASPLIT = 0.8                        #
Num_datos_entrada = 96                 #
Num_datos_salida = 96                  #
#---------------------------------------

def ventanas(dataset,xsize,ysize,split,validation= False):
  #dataset: Es un array de numpy obtenido a partir del dataframe de pandas, en este están contenidos todos los datos que se utilizarán
  #split: porcentaje del dataset a utilizar
  #xsize: Número entero, determina el tamaño de la ventana de caracteristicas (Entradas del modelo)
  #ysize: Número entero, determina el tamaño de la ventana de etiquetas (Salidas del modelo)
  #validation: Si es True, toma el porcentaje restante de los datos como set, de lo contrario toma el porcentaje indicado

  if validation!=True: #Se generan los índices para tomar los días exactos para el set de entrenamiento
    indexin=int(0)
    indexf=int((((len(dataset)*split)//xsize)*xsize))
  else: #Se generan los índices para tomar los días exactos para el set de validación
    indexin=int((((len(dataset)*split)//xsize)*xsize))
    indexf=int(len(dataset))
  n=0 # Indexador
  x=[] # Lista vacia donde estarán contenidas las ventanas de datos de entrada (Caracteristicas)
  y=[] # Lista vacia donde estarán contenidas las ventanas de datos de salida (Etiquetas)
  
  for i in range(int(((indexf-indexin)/ysize)-1)): #Este ciclo se repite el número de veces como ventanas habrán en un arreglo de datos
                                                   # Ejemplo: dataset= [1,2,3,4,5,6]
                                                   # indexf=6, indexin=0, xsize=2, ysize=2
                                                   # range= (3-1) = 2  <------ Ya que se obtendrán 3 ventanas de datos
                                                   # Al resultado se le resta uno para considerar que la ultima ventana tambien contenga datos en "y"
                                                   
    x.append(dataset[n+indexin:n+indexin+xsize].T) #Se agrega a la lista la ventana de datos utilizando la idexación 
                                                   # Ejemplo: dataset= [1,2,3,4,5,6]
                                                   # Primera iteración:
                                                   #  x=[[1,2]]
                                                   # Segunda iteración:
                                                   #  x=[[1,2],[3,4]]

    y.append(dataset[n+indexin+xsize:n+indexin+xsize+ysize].T[0])
                                                   # Siguiendo el ejemplo anterior
                                                   #  y=[[3,4]]
                                                   # Segunda iteración:
                                                   #  y=[[3,4],[5,6]]
    
                                                   # Siguiento el ejemplo, los las ventanas listas para entrar al modelo quedan de la siguiente manera
                                                   # x = [[1,2],[3,4]]
                                                   # y = [[3,4],[5,6]]

    n+=ysize # Se suma al indexador el tamaño de la ventana
    
  return np.array(x),np.array(y)

x_train1, y_train1= ventanas(dataset, xsize= Num_datos_entrada, ysize= Num_datos_salida, split = DATASPLIT)
x_val1,y_val1=ventanas(dataset, xsize= Num_datos_entrada, ysize= Num_datos_salida, split = DATASPLIT, validation=True)

# %%
x_train1.shape
# Out:
# (307, 1, 96)

# %% [markdown]
# ---
#
#
# # 5.   **FUNCIÓN PARA VISUALIZAR LOS RESULTADOS OBTENIDOS**
#
#
# ---

# %% [markdown]
# La siguiente de función se utiliza para generar gráficos a partir de una ventana de tiempo como las que se definieron anteriormente, esta se utilizará para mostrar:
#
# *   La ventana de tiempo utilizada para la predicción
# *   El valor real de los datos futuros tomado del set de validación
# *   El valor de las predicciones que arroja la red neuronal

# %%
def create_time_steps(length): # Función que crea un array en un rango determinado por el tamaño de la ventana de datos
    return list(range(-length, 0))

# history: Un arreglo con la ventana de datos usada para la predicción
# true_future: Arreglo con los datos conocidos que deberia arrojar la predicción 
# prediction: Arreglo con las predicciones obtenidas

def multi_step_plot(history, true_future, prediction): 
    plt.figure(figsize=(12, 6)) # Se define el tamaño de la figura
    num_in = create_time_steps(len(history)) #Tamaño de la curva de datos pasados
    num_out = len(true_future) # Tamaño de la curva de datos futuros
    plt.plot(num_in, history, label='History') # Graficamos datos pasados
    plt.plot(np.arange(num_out)/STEP, (true_future), 'y--',
           label='True Future') #Graficamos datos furutos
    if prediction.any(): # Si se ingresan datos sobre las predicciones
        plt.plot(np.arange(num_out)/STEP, (prediction), 'r--', #Grafica tambien las predicciones
                 label='Predicted Future')
    plt.legend(loc='upper left') # Ajustes de la grafica
    plt.grid()
    plt.show() # Se muestra la grafica

# %% [markdown]
# ---
#  # 6. **CREACIÓN Y ENTRENAMIENTO DEL MODELO**
#  ---

# %% [markdown]
# **GRU**: Es una parte de un modelo de red neuronal recurrente, que ayuda a ajustar los pesos de las entradas para resolver el problema del gradiente de desaparición, que es uno de los problemas que tienen las redes neuronales recurrentes el cual no les permite mantener la información a medida que se pasa de una red neuronal a otra.
#
# En las siguientes celdas se va a definir el modelo de ML que se utilizará para realizar las predicciones buscadas, este modelo consta de una capa de entrada, y dos capas intermedias de neuronas tipo LSTM, con una respectiva función de activación.
#
# ![RedNeuronalArtificial.png](https://upload.wikimedia.org/wikipedia/commons/thumb/5/5f/Gated_Recurrent_Unit.svg/470px-Gated_Recurrent_Unit.svg.png)
#
# Fig 1. [Diagrama de una red GRU](https://es.wikipedia.org/wiki/Perceptr%C3%B3n_multicapa)
#
# La cantidad de neuronas ajustada de forma manual para maximizar su precisión de entrenamiento y una capa de salida con n neuronas con n datos de predicción buscados.
#
# Además se compila el modelo y dentro de dicha compilación estan incluidas configuraciónes, donde las configuraciones son:
#
# *   **optimizer**: Optimizador utilizado
# *   **loss**: Métrica utilizada para determinar las perdidas del modelo
# *   **metrics**: Guarda los valores de las metricas en cada epoca de entrenamiento
#
# [Referencia](https://es.frwiki.wiki/wiki/R%C3%A9seau_de_neurones_r%C3%A9currents)

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('loss')<0.10):
      print("\nReached less than 0.02 losses so cancelling training!")
      self.model.stop_training = True
callbacks = myCallback()
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=70)

# %%
batch_size=1

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv1D(filters=32, kernel_size=3,padding="causal",activation="tanh", batch_input_shape= (batch_size, x_train1.shape[1], x_train1.shape[2])),
    tf.keras.layers.GRU(100, activation="tanh", stateful= True, dropout=0.2, return_sequences=True),
    tf.keras.layers.GRU(150, activation="tanh", stateful= True, dropout=0.2,return_sequences=True),
    tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(96))
])

model.compile(optimizer='adam', loss='mean_absolute_error')# Compilamos el modelo y definimos los ajustes ya explicados

# %%
history = model.fit(x_train1, y_train1, epochs=300, verbose=1, validation_data=(x_val1, y_val1), batch_size=batch_size, shuffle=False, callbacks=[early_stopping_cb, callbacks])
# Out:
# Epoch 1/300
# 307/307 [==============================] - 4s 6ms/step - loss: 0.2175 - val_loss: 0.1321
# Epoch 2/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1505 - val_loss: 0.1152
# Epoch 3/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1397 - val_loss: 0.1079
# Epoch 4/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1358 - val_loss: 0.1086
# Epoch 5/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1343 - val_loss: 0.1025
# Epoch 6/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1334 - val_loss: 0.1005
# Epoch 7/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1328 - val_loss: 0.1005
# Epoch 8/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1332 - val_loss: 0.1026
# Epoch 9/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1334 - val_loss: 0.1013
# Epoch 10/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1335 - val_loss: 0.1004
# Epoch 11/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1334 - val_loss: 0.1004
# Epoch 12/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1335 - val_loss: 0.1001
# Epoch 13/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1333 - val_loss: 0.0987
# Epoch 14/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1331 - val_loss: 0.0985
# Epoch 15/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1336 - val_loss: 0.1000
# Epoch 16/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1339 - val_loss: 0.0971
# Epoch 17/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1340 - val_loss: 0.0972
# Epoch 18/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1342 - val_loss: 0.0972
# Epoch 19/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1342 - val_loss: 0.0972
# Epoch 20/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1343 - val_loss: 0.0976
# Epoch 21/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1343 - val_loss: 0.0964
# Epoch 22/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1348 - val_loss: 0.0974
# Epoch 23/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1352 - val_loss: 0.0971
# Epoch 24/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1354 - val_loss: 0.0965
# Epoch 25/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1357 - val_loss: 0.0971
# Epoch 26/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1368 - val_loss: 0.0973
# Epoch 27/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1360 - val_loss: 0.0971
# Epoch 28/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1370 - val_loss: 0.0970
# Epoch 29/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1368 - val_loss: 0.0962
# Epoch 30/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1369 - val_loss: 0.0973
# Epoch 31/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1371 - val_loss: 0.0966
# Epoch 32/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1370 - val_loss: 0.0964
# Epoch 33/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1373 - val_loss: 0.0966
# Epoch 34/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1368 - val_loss: 0.0969
# Epoch 35/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1365 - val_loss: 0.0965
# Epoch 36/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1368 - val_loss: 0.0962
# Epoch 37/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1372 - val_loss: 0.0961
# Epoch 38/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1369 - val_loss: 0.0959
# Epoch 39/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1376 - val_loss: 0.0965
# Epoch 40/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1374 - val_loss: 0.0966
# Epoch 41/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1378 - val_loss: 0.0963
# Epoch 42/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1379 - val_loss: 0.0970
# Epoch 43/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1377 - val_loss: 0.0967
# Epoch 44/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1375 - val_loss: 0.0960
# Epoch 45/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1375 - val_loss: 0.0960
# Epoch 46/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1383 - val_loss: 0.0962
# Epoch 47/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1380 - val_loss: 0.0963
# Epoch 48/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1379 - val_loss: 0.0960
# Epoch 49/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1376 - val_loss: 0.0963
# Epoch 50/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1380 - val_loss: 0.0961
# Epoch 51/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1386 - val_loss: 0.0974
# Epoch 52/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1386 - val_loss: 0.0964
# Epoch 53/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1414 - val_loss: 0.0963
# Epoch 54/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1339 - val_loss: 0.0960
# Epoch 55/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1348 - val_loss: 0.0956
# Epoch 56/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1352 - val_loss: 0.0960
# Epoch 57/300
# 307/307 [==============================] - 2s 6ms/step - loss: 0.1361 - val_loss: 0.0961
# Epoch 58/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1366 - val_loss: 0.0958
# Epoch 59/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1368 - val_loss: 0.0960
# Epoch 60/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1370 - val_loss: 0.0960
# Epoch 61/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1374 - val_loss: 0.0960
# Epoch 62/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1375 - val_loss: 0.0962
# Epoch 63/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1377 - val_loss: 0.0959
# Epoch 64/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1378 - val_loss: 0.0959
# Epoch 65/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1381 - val_loss: 0.0956
# Epoch 66/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1385 - val_loss: 0.0960
# Epoch 67/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1388 - val_loss: 0.0959
# Epoch 68/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1390 - val_loss: 0.0960
# Epoch 69/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1384 - val_loss: 0.0956
# Epoch 70/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1384 - val_loss: 0.0957
# Epoch 71/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1377 - val_loss: 0.0962
# Epoch 72/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1383 - val_loss: 0.0969
# Epoch 73/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1375 - val_loss: 0.0961
# Epoch 74/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1377 - val_loss: 0.0960
# Epoch 75/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1377 - val_loss: 0.0957
# Epoch 76/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1379 - val_loss: 0.0961
# Epoch 77/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1380 - val_loss: 0.0959
# Epoch 78/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1380 - val_loss: 0.0962
# Epoch 79/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1378 - val_loss: 0.0957
# Epoch 80/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1382 - val_loss: 0.0960
# Epoch 81/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1384 - val_loss: 0.0957
# Epoch 82/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1386 - val_loss: 0.0964
# Epoch 83/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1382 - val_loss: 0.0959
# Epoch 84/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1388 - val_loss: 0.0957
# Epoch 85/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1393 - val_loss: 0.0961
# Epoch 86/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1398 - val_loss: 0.0958
# Epoch 87/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1398 - val_loss: 0.0954
# Epoch 88/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1400 - val_loss: 0.0956
# Epoch 89/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1399 - val_loss: 0.0955
# Epoch 90/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1397 - val_loss: 0.0959
# Epoch 91/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1393 - val_loss: 0.0969
# Epoch 92/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1411 - val_loss: 0.0963
# Epoch 93/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1389 - val_loss: 0.0961
# Epoch 94/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1390 - val_loss: 0.0956
# Epoch 95/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1386 - val_loss: 0.0953
# Epoch 96/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1385 - val_loss: 0.0958
# Epoch 97/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1386 - val_loss: 0.0958
# Epoch 98/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1387 - val_loss: 0.0957
# Epoch 99/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1388 - val_loss: 0.0957
# Epoch 100/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1384 - val_loss: 0.0958
# Epoch 101/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1383 - val_loss: 0.0955
# Epoch 102/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1388 - val_loss: 0.0958
# Epoch 103/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1390 - val_loss: 0.0957
# Epoch 104/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1392 - val_loss: 0.0960
# Epoch 105/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1392 - val_loss: 0.0959
# Epoch 106/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1394 - val_loss: 0.0953
# Epoch 107/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1392 - val_loss: 0.0959
# Epoch 108/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1394 - val_loss: 0.0955
# Epoch 109/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1395 - val_loss: 0.0954
# Epoch 110/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1394 - val_loss: 0.0957
# Epoch 111/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1393 - val_loss: 0.0952
# Epoch 112/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1394 - val_loss: 0.0958
# Epoch 113/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1394 - val_loss: 0.0954
# Epoch 114/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1395 - val_loss: 0.0955
# Epoch 115/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1397 - val_loss: 0.0956
# Epoch 116/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1396 - val_loss: 0.0957
# Epoch 117/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1395 - val_loss: 0.0951
# Epoch 118/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1395 - val_loss: 0.0960
# Epoch 119/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1396 - val_loss: 0.0955
# Epoch 120/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1399 - val_loss: 0.0957
# Epoch 121/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1398 - val_loss: 0.0959
# Epoch 122/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1394 - val_loss: 0.0955
# Epoch 123/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1394 - val_loss: 0.0955
# Epoch 124/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1389 - val_loss: 0.0957
# Epoch 125/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1395 - val_loss: 0.0959
# Epoch 126/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1392 - val_loss: 0.0954
# Epoch 127/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1390 - val_loss: 0.0954
# Epoch 128/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1393 - val_loss: 0.0954
# Epoch 129/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1393 - val_loss: 0.0953
# Epoch 130/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1395 - val_loss: 0.0956
# Epoch 131/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1395 - val_loss: 0.0955
# Epoch 132/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1395 - val_loss: 0.0956
# Epoch 133/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1396 - val_loss: 0.0954
# Epoch 134/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1395 - val_loss: 0.0957
# Epoch 135/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1397 - val_loss: 0.0955
# Epoch 136/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1397 - val_loss: 0.0956
# Epoch 137/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1396 - val_loss: 0.0952
# Epoch 138/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1399 - val_loss: 0.0956
# Epoch 139/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1395 - val_loss: 0.0954
# Epoch 140/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1398 - val_loss: 0.0957
# Epoch 141/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1397 - val_loss: 0.0957
# Epoch 142/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1400 - val_loss: 0.0954
# Epoch 143/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1401 - val_loss: 0.0957
# Epoch 144/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1400 - val_loss: 0.0951
# Epoch 145/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1403 - val_loss: 0.0956
# Epoch 146/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1399 - val_loss: 0.0955
# Epoch 147/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1402 - val_loss: 0.0954
# Epoch 148/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1400 - val_loss: 0.0955
# Epoch 149/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1402 - val_loss: 0.0953
# Epoch 150/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1400 - val_loss: 0.0955
# Epoch 151/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1394 - val_loss: 0.0953
# Epoch 152/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1395 - val_loss: 0.0958
# Epoch 153/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1404 - val_loss: 0.0955
# Epoch 154/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1405 - val_loss: 0.0957
# Epoch 155/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1401 - val_loss: 0.0957
# Epoch 156/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1397 - val_loss: 0.0953
# Epoch 157/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1396 - val_loss: 0.0956
# Epoch 158/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1397 - val_loss: 0.0960
# Epoch 159/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1395 - val_loss: 0.0952
# Epoch 160/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1397 - val_loss: 0.0956
# Epoch 161/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1397 - val_loss: 0.0953
# Epoch 162/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1398 - val_loss: 0.0954
# Epoch 163/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1400 - val_loss: 0.0954
# Epoch 164/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1400 - val_loss: 0.0954
# Epoch 165/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1402 - val_loss: 0.0953
# Epoch 166/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1403 - val_loss: 0.0952
# Epoch 167/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1402 - val_loss: 0.0953
# Epoch 168/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1403 - val_loss: 0.0954
# Epoch 169/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1402 - val_loss: 0.0954
# Epoch 170/300
# 307/307 [==============================] - 1s 4ms/step - loss: 0.1402 - val_loss: 0.0953
# Epoch 171/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1402 - val_loss: 0.0954
# Epoch 172/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1403 - val_loss: 0.0954
# Epoch 173/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1401 - val_loss: 0.0952
# Epoch 174/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1402 - val_loss: 0.0952
# Epoch 175/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1401 - val_loss: 0.0951
# Epoch 176/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1404 - val_loss: 0.0953
# Epoch 177/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1404 - val_loss: 0.0953
# Epoch 178/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1403 - val_loss: 0.0951
# Epoch 179/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1404 - val_loss: 0.0956
# Epoch 180/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1402 - val_loss: 0.0951
# Epoch 181/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1403 - val_loss: 0.0953
# Epoch 182/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1402 - val_loss: 0.0957
# Epoch 183/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1404 - val_loss: 0.0956
# Epoch 184/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1402 - val_loss: 0.0953
# Epoch 185/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1404 - val_loss: 0.0953
# Epoch 186/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1403 - val_loss: 0.0955
# Epoch 187/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1405 - val_loss: 0.0953
# Epoch 188/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1403 - val_loss: 0.0951
# Epoch 189/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1405 - val_loss: 0.0953
# Epoch 190/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1404 - val_loss: 0.0950
# Epoch 191/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1404 - val_loss: 0.0955
# Epoch 192/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1403 - val_loss: 0.0951
# Epoch 193/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1405 - val_loss: 0.0955
# Epoch 194/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1403 - val_loss: 0.0952
# Epoch 195/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1404 - val_loss: 0.0955
# Epoch 196/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1403 - val_loss: 0.0951
# Epoch 197/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1405 - val_loss: 0.0955
# Epoch 198/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1404 - val_loss: 0.0952
# Epoch 199/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1405 - val_loss: 0.0953
# Epoch 200/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1404 - val_loss: 0.0953
# Epoch 201/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1406 - val_loss: 0.0952
# Epoch 202/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1404 - val_loss: 0.0953
# Epoch 203/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1407 - val_loss: 0.0952
# Epoch 204/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1405 - val_loss: 0.0952
# Epoch 205/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1406 - val_loss: 0.0954
# Epoch 206/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1403 - val_loss: 0.0951
# Epoch 207/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1406 - val_loss: 0.0955
# Epoch 208/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1405 - val_loss: 0.0951
# Epoch 209/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1405 - val_loss: 0.0952
# Epoch 210/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1406 - val_loss: 0.0952
# Epoch 211/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1406 - val_loss: 0.0952
# Epoch 212/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1407 - val_loss: 0.0951
# Epoch 213/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1406 - val_loss: 0.0953
# Epoch 214/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1407 - val_loss: 0.0948
# Epoch 215/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1408 - val_loss: 0.0952
# Epoch 216/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1407 - val_loss: 0.0952
# Epoch 217/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1405 - val_loss: 0.0951
# Epoch 218/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1407 - val_loss: 0.0953
# Epoch 219/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1408 - val_loss: 0.0954
# Epoch 220/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1409 - val_loss: 0.0952
# Epoch 221/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1409 - val_loss: 0.0953
# Epoch 222/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1408 - val_loss: 0.0948
# Epoch 223/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1410 - val_loss: 0.0957
# Epoch 224/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1406 - val_loss: 0.0950
# Epoch 225/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1409 - val_loss: 0.0951
# Epoch 226/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1410 - val_loss: 0.0952
# Epoch 227/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1411 - val_loss: 0.0950
# Epoch 228/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1408 - val_loss: 0.0952
# Epoch 229/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1398 - val_loss: 0.0952
# Epoch 230/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1400 - val_loss: 0.0955
# Epoch 231/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1400 - val_loss: 0.0954
# Epoch 232/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1398 - val_loss: 0.0957
# Epoch 233/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1399 - val_loss: 0.0954
# Epoch 234/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1399 - val_loss: 0.0955
# Epoch 235/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1402 - val_loss: 0.0956
# Epoch 236/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1400 - val_loss: 0.0950
# Epoch 237/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1404 - val_loss: 0.0954
# Epoch 238/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1402 - val_loss: 0.0952
# Epoch 239/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1404 - val_loss: 0.0955
# Epoch 240/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1404 - val_loss: 0.0952
# Epoch 241/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1403 - val_loss: 0.0953
# Epoch 242/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1403 - val_loss: 0.0953
# Epoch 243/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1404 - val_loss: 0.0955
# Epoch 244/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1407 - val_loss: 0.0951
# Epoch 245/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1406 - val_loss: 0.0952
# Epoch 246/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1407 - val_loss: 0.0955
# Epoch 247/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1405 - val_loss: 0.0960
# Epoch 248/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1403 - val_loss: 0.0957
# Epoch 249/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1403 - val_loss: 0.0956
# Epoch 250/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1404 - val_loss: 0.0953
# Epoch 251/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1405 - val_loss: 0.0954
# Epoch 252/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1404 - val_loss: 0.0950
# Epoch 253/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1405 - val_loss: 0.0952
# Epoch 254/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1407 - val_loss: 0.0966
# Epoch 255/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1401 - val_loss: 0.0959
# Epoch 256/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1401 - val_loss: 0.0952
# Epoch 257/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1404 - val_loss: 0.0951
# Epoch 258/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1403 - val_loss: 0.0953
# Epoch 259/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1406 - val_loss: 0.0953
# Epoch 260/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1406 - val_loss: 0.0952
# Epoch 261/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1407 - val_loss: 0.0954
# Epoch 262/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1405 - val_loss: 0.0948
# Epoch 263/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1415 - val_loss: 0.0949
# Epoch 264/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1416 - val_loss: 0.0950
# Epoch 265/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1415 - val_loss: 0.0951
# Epoch 266/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1412 - val_loss: 0.0954
# Epoch 267/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1414 - val_loss: 0.0952
# Epoch 268/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1408 - val_loss: 0.0957
# Epoch 269/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1407 - val_loss: 0.0984
# Epoch 270/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1407 - val_loss: 0.0969
# Epoch 271/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1401 - val_loss: 0.0983
# Epoch 272/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1401 - val_loss: 0.0965
# Epoch 273/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1397 - val_loss: 0.0963
# Epoch 274/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1398 - val_loss: 0.0956
# Epoch 275/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1399 - val_loss: 0.0961
# Epoch 276/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1399 - val_loss: 0.0982
# Epoch 277/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1402 - val_loss: 0.0968
# Epoch 278/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1402 - val_loss: 0.0962
# Epoch 279/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1410 - val_loss: 0.0967
# Epoch 280/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1401 - val_loss: 0.0963
# Epoch 281/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1398 - val_loss: 0.0973
# Epoch 282/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1406 - val_loss: 0.0965
# Epoch 283/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.1388 - val_loss: 0.0961
# Epoch 284/300
# 307/307 [==============================] - 1s 5ms/step - loss: 0.1386 - val_loss: 0.0964

# %% [markdown]
# ---
#
#
# # 7. **RESULTADOS Y ANÁLISIS** 📃
#
#
# ---

# %% [markdown]
# En esta sección del codigo se observarán y analizarán los resultados obtenidos realizando predicciones con el modelo que generamos.  ✌

# %%
model.evaluate(x_val1, y_val1),model.evaluate(x_train1, y_train1)
# Out:
# 3/3 [==============================] - 1s 7ms/step - loss: 0.0981
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1811
# (0.09809784591197968, 0.18105612695217133)

# %%
def metricas(history):
  loss     = history.history[    'loss' ]
  val_loss = history.history['val_loss' ]


  epochs   = range(1,len(loss)+1,1)
  plt.plot ( epochs,     loss, 'r--', label='Training loss' )
  plt.plot ( epochs, val_loss ,  'b', label='Validation loss' )
  plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
  plt.title ('Training and Validation losses'   )
  plt.ylabel('Loss')
  plt.xlabel('Epochs')
  plt.grid(True)

  plt.legend()
  plt.figure() 

metricas(history)

# %% [markdown]
# **CÁLCULO DE ERRORES**

# %%
n=0
MAPE = []
MAE = []
RMSE = []
for i in range(len(x_train1)):
  xt= x_train1[n][0]
  yt= y_train1[n]
  y=model.predict(np.array([x_train1[n]]))[0][0]
  xt= scaler.inverse_transform(xt.reshape((96,1))).reshape((1,96))
  yt= scaler.inverse_transform(yt.reshape((96,1))).reshape((1,96)) 
  y=scaler.inverse_transform(y.reshape((96,1))).reshape((1,96))
  mape = np.divide(abs(yt-y), yt, out=np.zeros_like(abs(yt-y)), where=abs(yt)>=1).mean()
  mae = mean_absolute_error(yt,y)
  rmse = mean_squared_error(yt,y)**0.5

  MAPE.append(mape)
  MAE.append(mae)
  RMSE.append(rmse)
  n+=1
tMAPE =np.array(MAPE).mean()
tMAE =np.array(MAE).mean()
tRMSE =np.array(RMSE).mean()

n=0
MAPE = []
MAE = []
RMSE = []
for i in range(len(x_val1)):
  xt= x_val1[n][0]
  yt= y_val1[n]
  y=model.predict(np.array([x_val1[n]]))[0][0]
  xt= scaler.inverse_transform(xt.reshape((96,1))).reshape((1,96))
  yt= scaler.inverse_transform(yt.reshape((96,1))).reshape((1,96)) 
  y=scaler.inverse_transform(y.reshape((96,1))).reshape((1,96))
  mape = np.divide(abs(yt-y), yt, out=np.zeros_like(abs(yt-y)), where=abs(yt)>=1).mean()
  mae = mean_absolute_error(yt,y)
  rmse = mean_squared_error(yt,y)**0.5

  MAPE.append(mape)
  MAE.append(mae)
  RMSE.append(rmse)
  n+=1
  
vMAPE =np.array(MAPE).mean()
vMAE =np.array(MAE).mean()
vRMSE =np.array(RMSE).mean()

# %%
print("----------------------------------")
print("|  MAE   |   MAPE[%] |       RMSE  |    <-------- Promedio de errores del set completo de entrenamiento")
print("----------------------------------")
print("%9.4f%12.4f%12.4f"%(tMAE,tMAPE,tRMSE))
print("----------------------------------")
print("|  MAE   |   MAPE[%] |       RMSE  |    <-------- Promedio de errores del set completo de validación")
print("----------------------------------")
print("%9.4f%12.4f%12.4f"%(vMAE,vMAPE,vRMSE))
print("----------------------------------")
# Out:
# ----------------------------------
# |  MAE   |   MAPE[%] |       RMSE  |    <-------- Promedio de errores del set completo de entrenamiento
# ----------------------------------
#   77.1702      0.4054    127.8861
# ----------------------------------
# |  MAE   |   MAPE[%] |       RMSE  |    <-------- Promedio de errores del set completo de validación
# ----------------------------------
#   46.4782      0.1789     80.8792
# ----------------------------------

# %% [markdown]
# ----------------------------------
# |  MAE   |   MAPE[%] |       RMSE  |    <-------- Promedio de errores del set completo de entrenamiento
# ----------------------------------
#  106.0432      0.4545    163.6624
# ----------------------------------
# |  MAE   |   MAPE[%] |       RMSE  |    <-------- Promedio de errores del set completo de validación
# ----------------------------------
#   61.3884      0.5668     99.3021
# ----------------------------------

# %% [markdown]
# **CON LOS DATOS DE ENTRENAMIENTO**

# %%
STEP = 1
n=0
for i in range(5):
  xt= x_train1[n][0]
  yt= y_train1[n]
  y=model.predict(np.array([x_train1[n]]))[0][0]
  mae= abs((y-yt).mean())
  xt= scaler.inverse_transform(xt.reshape((96,1))).reshape((1,96))
  yt= scaler.inverse_transform(yt.reshape((96,1))).reshape((1,96)) 
  y=scaler.inverse_transform(y.reshape((96,1))).reshape((1,96))

  multi_step_plot(xt[0], yt[0], y[0])
  print('El MAPE para un horizonte de 24h es:',mae*100,'%')
  n+=1
# Out:
# El MAPE para un horizonte de 24h es: 3.956904500732151 %
# El MAPE para un horizonte de 24h es: 10.739446929897325 %
# El MAPE para un horizonte de 24h es: 2.325687833433868 %
# El MAPE para un horizonte de 24h es: 1.8597554901785374 %
# El MAPE para un horizonte de 24h es: 4.109587253331465 %

# %% [markdown]
# **CON LOS DATOS DE VALIDACIÓN**

# %%
STEP = 1
n=0
for i in range(5):
  xt= x_val1[n][0]
  yt= y_val1[n]
  y=model.predict(np.array([x_val1[n]]))[0][0]
  mae= abs((y-yt).mean())
  xt= scaler.inverse_transform(xt.reshape((96,1))).reshape((1,96))
  yt= scaler.inverse_transform(yt.reshape((96,1))).reshape((1,96)) 
  y=scaler.inverse_transform(y.reshape((96,1))).reshape((1,96))

  multi_step_plot(xt[0], yt[0], y[0])
  print('El MAPE para un horizonte de 24h es:',mae*100,'%')
  n+=1
# Out:
# El MAPE para un horizonte de 24h es: 4.017225238083582 %
# El MAPE para un horizonte de 24h es: 0.02809792276172145 %
# El MAPE para un horizonte de 24h es: 1.7328782136351435 %
# El MAPE para un horizonte de 24h es: 1.972597938684585 %
# El MAPE para un horizonte de 24h es: 10.584121654475258 %
